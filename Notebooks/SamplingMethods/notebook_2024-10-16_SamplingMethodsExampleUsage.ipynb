# %%
import os
from SamplingMethods import Sampler_class

# %% [markdown]
# # 1D Parameter Space

# %%
Parameters_lis = [
            {"name":"x1", "type":"range","bounds":[0.0,1.0],"value_type":"float"}
        ]
NoS_int = 4
Splr_obj = Sampler_class()
x_mat = Splr_obj.one.GridSampler1D_func(NoS_int,Parameters_lis)
Splr_obj.one.Plot1D_func(x_mat)

# %%
Parameters_lis = [
            {"name":"x1", "type":"range","bounds":[0.0,1.0],"value_type":"float"}
        ]
NoS_int = 4
Splr_obj = Sampler_class()
x_mat = Splr_obj.one.PseudorandomSampler1D_func(NoS_int,Parameters_lis)
Splr_obj.one.Plot1D_func(x_mat)

# %%
Parameters_lis = [
            {"name":"x1", "type":"range","bounds":[0.0,1.0],"value_type":"float"}
        ]
NoS_int = 4
Splr_obj = Sampler_class()
x_mat = Splr_obj.one.QuasirandomSampler1D_func(NoS_int,Parameters_lis)
Splr_obj.one.Plot1D_func(x_mat)

# %% [markdown]
# # 2D Parameter Space

# %%
Parameters_lis = [
            {"name":"x1", "type":"range","bounds":[0.0,1.0],"value_type":"float"},
            {"name":"x2", "type":"range","bounds":[0.0,1.0],"value_type":"float"}
        ]
NoS_int = 8
Splr_obj = Sampler_class()
x_mat = Splr_obj.two.GridSampler2D_func(NoS_int,Parameters_lis)
Splr_obj.two.Plot2D_func(x_mat)
# Out:
# Samples gridded = 9

# %%
Parameters_lis = [
            {"name":"x1", "type":"range","bounds":[0.0,1.0],"value_type":"float"},
            {"name":"x2", "type":"range","bounds":[0.0,1.0],"value_type":"float"}
        ]
NoS_int = 8
Splr_obj = Sampler_class()
x_mat = Splr_obj.two.PseudorandomSampler2D_func(NoS_int,Parameters_lis)
Splr_obj.two.Plot2D_func(x_mat)

# %%
Parameters_lis = [
            {"name":"x1", "type":"range","bounds":[0.0,1.0],"value_type":"float"},
            {"name":"x2", "type":"range","bounds":[0.0,1.0],"value_type":"float"}
        ]
NoS_int = 8
Splr_obj = Sampler_class()
x_mat = Splr_obj.two.QuasirandomSampler2D_func(NoS_int,Parameters_lis)
Splr_obj.two.Plot2D_func(x_mat)

# %% [markdown]
# # 3D Parameter Space

# %%
Parameters_lis = [
            {"name":"x1", "type":"range","bounds":[0.0,1.0],"value_type":"float"},
            {"name":"x2", "type":"range","bounds":[0.0,1.0],"value_type":"float"},
            {"name":"x3", "type":"range","bounds":[0.0,1.0],"value_type":"float"}
        ]
NoS_int = 27
Splr_obj = Sampler_class()
x_mat = Splr_obj.three.GridSampler3D_func(NoS_int,Parameters_lis)
Splr_obj.three.Plot3D_func(x_mat)
# Out:
# Samples gridded = 27

# %%
Parameters_lis = [
            {"name":"x1", "type":"range","bounds":[0.0,1.0],"value_type":"float"},
            {"name":"x2", "type":"range","bounds":[0.0,1.0],"value_type":"float"},
            {"name":"x3", "type":"range","bounds":[0.0,1.0],"value_type":"float"}
        ]
NoS_int = 27
Splr_obj = Sampler_class()
x_mat = Splr_obj.three.PseudorandomSampler3D_func(NoS_int,Parameters_lis)
Splr_obj.three.Plot3D_func(x_mat)

# %%
Parameters_lis = [
            {"name":"x1", "type":"range","bounds":[0.0,1.0],"value_type":"float"},
            {"name":"x2", "type":"range","bounds":[0.0,1.0],"value_type":"float"},
            {"name":"x3", "type":"range","bounds":[0.0,1.0],"value_type":"float"}
        ]
NoS_int = 27
Splr_obj = Sampler_class()
x_mat = Splr_obj.three.QuasirandomSampler3D_func(NoS_int,Parameters_lis)
Splr_obj.three.Plot3D_func(x_mat)

# %%
x_mat
# Out:
# array([[0.58659401, 0.31673687, 0.44676851, 0.71668937, 0.11348159,
#         0.17870305, 0.98486586, 0.65191518, 0.3815471 , 0.25145204,
#         0.52188336, 0.04879841, 0.09346413, 0.87525206, 0.5584041 ,
#         0.27991089, 0.40994279, 0.68849922, 0.22343255, 0.15814319,
#         0.94044157, 0.75321422, 0.4752322 , 0.34513689, 0.62318263,
#         0.81047347, 0.02823832],
#        [0.23910788, 0.72887017, 0.10446415, 0.60236737, 0.88557429,
#         0.11293621, 0.65908175, 0.40000273, 0.89386004, 0.26447502,
#         0.76647178, 0.52558841, 0.03643892, 0.54248336, 0.28162685,
#         0.81558552, 0.41614438, 0.94196063, 0.67497248, 0.32635883,
#         0.83643276, 0.05557354, 0.58550023, 0.19122843, 0.71301518,
#         0.45183721, 0.97005381],
#        [0.54029498, 0.19040746, 0.45769281, 0.82379612, 0.72812004,
#         0.04975179, 0.67485732, 0.39730081, 0.8761861 , 0.60877638,
#         0.11367035, 0.3352858 , 0.64982256, 0.10493751, 0.83899765,
# ...

# %%
for i in range(6):
    print(x_mat.T[:][i])
# Out:
# [0.58659401 0.23910788 0.54029498]
# [0.31673687 0.72887017 0.19040746]
# [0.44676851 0.10446415 0.45769281]
# [0.71668937 0.60236737 0.82379612]
# [0.11348159 0.88557429 0.72812004]
# [0.17870305 0.11293621 0.04975179]
