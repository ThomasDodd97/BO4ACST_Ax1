# %% [markdown]
# # Optimising Unknown Curing System: 'Method20241026Dim3'
#
# Settings:
# * Space-Filling Technique: Grid (1 * 27)
# * Sequential Technique: MIP (4 * 1)

# %% [markdown]
# # Nødvendig Bestanddel:

# %%
from ConfigFile import OptimisationSetup_class
from ExperimentalMethods import ExperimentalMethods_class
from PlottingMethods import PlottingMethods_class

# %%
# Instantiate the optimisation configuration class object.
OptimisationSetup_obj = OptimisationSetup_class()
# Instantiate the experimental methods class object.
ExperimentalMethods_obj = ExperimentalMethods_class()

# %%
# Use the initialiser function to import the current experiment or begin a new one.
AxClient_obj = ExperimentalMethods_obj.ExperimentInitialiser_func(OptimisationSetup_obj)
# Out:
# [INFO 11-05 10:14:18] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [INFO 11-05 10:14:18] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# The current experiment has been initialised.

# %% [markdown]
# # Stykke 0 - Plot

# %%
Plotter_obj = PlottingMethods_class()
Plotter_obj.InteractivePlot(AxClient_obj,OptimisationSetup_obj)
# Out:
# [WARNING 11-05 10:14:18] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# 3D Interactive Plot
# interactive(children=(IntSlider(value=25, description='Elevation', max=90, min=-90, step=5), IntSlider(value=5…

# %% [markdown]
# # Stykke 1 - Begyndelsen

# %%
df = AxClient_obj.get_trials_data_frame()
df
# Out:
# [WARNING 11-05 10:13:47] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
#     trial_index arm_name trial_status generation_method         t1        x1  \
# 0             0      0_0    COMPLETED            Manual  50.487485  0.526302
# 1             1      1_0    COMPLETED            Manual  50.487485  0.628629
# 2             2      2_0    COMPLETED            Manual  50.487485  0.397679
# 3             3      3_0    COMPLETED            Manual  50.487485  0.452311
# 4             4      4_0    COMPLETED            Manual  50.487485  0.576961
# 5             5      5_0    COMPLETED            Manual  50.487485  0.480570
# 6             6      6_0    COMPLETED            Manual  50.487485  0.348583
# 7             7      7_0    COMPLETED            Manual  50.487485  0.383995
# 8             8      8_0    COMPLETED            Manual  50.487485  0.508613
# 9             9      9_0    COMPLETED            Manual  50.487485  0.590711
# 10           10     10_0    COMPLETED            Manual  50.487485  0.458779
# 11           11     11_0    COMPLETED            Manual  50.487485  0.412818
# 12           12     12_0    COMPLETED            Manual  50.487485  0.639286
# 13           13     13_0    COMPLETED            Manual  50.487485  0.563102
# 14           14     14_0    COMPLETED            Manual  50.487485  0.332120
# 15           15     15_0    COMPLETED            Manual  50.487485  0.305166
# 16           16     16_0    COMPLETED            Manual  50.487485  0.301661
# 17           17     17_0    COMPLETED            Manual  50.487485  0.300598
# 18           18     18_0    COMPLETED            Manual  50.487485  0.645058
#
#           x2        x3
# 0   0.999266  0.600101
# 1   0.990188  0.764140
# 2   0.996250  0.509904
# 3   0.991732  0.649030
# 4   0.995379  0.802816
# 5   0.993564  0.562814
# 6   0.997189  0.715015
# 7   0.990566  0.573835
# 8   0.996630  0.726008
# 9   0.992388  0.689234
# 10  0.998432  0.842997
# 11  0.994396  0.778125
# 12  0.998024  0.523909
# 13  0.991354  0.892720
# 14  0.994999  0.636922
# 15  0.990373  0.899493
# 16  0.993006  0.519949
# 17  0.998907  0.797669
# 18  0.990945  0.614729

# %%
# Initiate the current trials.
ExperimentalMethods_obj.TrialsStartor_func(AxClient_obj,OptimisationSetup_obj)
df = AxClient_obj.get_trials_data_frame()
df
# Out:
# [WARNING 11-05 10:13:48] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-05 10:13:48] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-05 10:13:51] ax.core.experiment: Attached custom parameterizations [{'x1': 0.649286, 'x2': 0.993981, 'x3': 0.865395}] as trial 19.
# [INFO 11-05 10:13:51] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241026Dim3_CuringSys_MIP/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-05 10:13:51] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
#     trial_index arm_name trial_status generation_method         t1        x1  \
# 0             0      0_0    COMPLETED            Manual  50.487485  0.526302
# 1             1      1_0    COMPLETED            Manual  50.487485  0.628629
# 2             2      2_0    COMPLETED            Manual  50.487485  0.397679
# 3             3      3_0    COMPLETED            Manual  50.487485  0.452311
# 4             4      4_0    COMPLETED            Manual  50.487485  0.576961
# 5             5      5_0    COMPLETED            Manual  50.487485  0.480570
# 6             6      6_0    COMPLETED            Manual  50.487485  0.348583
# 7             7      7_0    COMPLETED            Manual  50.487485  0.383995
# 8             8      8_0    COMPLETED            Manual  50.487485  0.508613
# 9             9      9_0    COMPLETED            Manual  50.487485  0.590711
# 10           10     10_0    COMPLETED            Manual  50.487485  0.458779
# 11           11     11_0    COMPLETED            Manual  50.487485  0.412818
# 12           12     12_0    COMPLETED            Manual  50.487485  0.639286
# 13           13     13_0    COMPLETED            Manual  50.487485  0.563102
# 14           14     14_0    COMPLETED            Manual  50.487485  0.332120
# 15           15     15_0    COMPLETED            Manual  50.487485  0.305166
# 16           16     16_0    COMPLETED            Manual  50.487485  0.301661
# 17           17     17_0    COMPLETED            Manual  50.487485  0.300598
# 18           18     18_0    COMPLETED            Manual  50.487485  0.645058
# 19           19     19_0      RUNNING            Manual        NaN  0.649286
#
#           x2        x3
# 0   0.999266  0.600101
# 1   0.990188  0.764140
# 2   0.996250  0.509904
# 3   0.991732  0.649030
# 4   0.995379  0.802816
# 5   0.993564  0.562814
# 6   0.997189  0.715015
# 7   0.990566  0.573835
# 8   0.996630  0.726008
# 9   0.992388  0.689234
# 10  0.998432  0.842997
# 11  0.994396  0.778125
# 12  0.998024  0.523909
# 13  0.991354  0.892720
# 14  0.994999  0.636922
# 15  0.990373  0.899493
# 16  0.993006  0.519949
# 17  0.998907  0.797669
# 18  0.990945  0.614729
# 19  0.993981  0.865395

# %%
# Carry out the experimentation associated with the current trials.
ExperimentalMethods_obj.TrialsExecutor_func(AxClient_obj,OptimisationSetup_obj)
# Out:
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-05 10:13:51] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-05 10:13:51] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# Trials are running. - Searching for parameterisation backup file
# Backup file available!
# Running trials have not executed by the operator - executing...
# Retrieving trials.
#
# ===== Preliminary Setup =====
# Pre-Heat the Oven to 80oC.
# Continue? (y)
# 		Input:  y
#
# ===== Initial Pouring of StockUPR1 =====
# Use a P10mL pipette set to 2 ml to transfer StockUPR1 to 1 mould gaps.
#
# -----Trial 19-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# ===== Mixing UPR1 from StockUPR1 & DeI =====
#
# -----Trial 19-----
# Add 0.114 g DeI
# Use P200 equipped with D200.
# Set to 117.502 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# ===== Mixing AUPR1 from UPR1 & DMA =====
#
# -----Trial 19-----
# Add 0.0128 g DMA
# Use P20 equipped with D200.
# Set to 13.148 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# ===== Mixing IAUPR1 from AUPR1 & I1 =====
#
# -----Trial 19-----
# Add 0.33 g I1
# Continue? (y)
# 		Input:  y
#
# ===== Curing Regime =====
# Stage1: 180 mins @ 80 oC
# Stage2: 60 mins @ 120 oC

# %% [markdown]
# # Stykke 2 - Enden

# %%
# Complete the current trials.
ExperimentalMethods_obj.TrialsCompletor_func(AxClient_obj,OptimisationSetup_obj)
# Out:
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-05 10:14:12] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-05 10:14:12] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-05 10:14:12] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# There are trials running!
# Backup file available!
# There are trials that can be completed.
# Mechanical Test Data Available - trials can be completed.
# The dimensional dataframe is up to date - extracting mechanical test data for evaluation.
# Were the fits acceptable?
# [INFO 11-05 10:14:14] ax.service.ax_client: Completed trial 19 with data: {'t1': (50.487485, None)}.
# [INFO 11-05 10:14:14] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241026Dim3_CuringSys_MIP/AxExperiment.json`.
# 		Input:  y

# %%
df = AxClient_obj.get_trials_data_frame()
df
# Out:
# [WARNING 11-05 10:14:14] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
#     trial_index arm_name trial_status generation_method         t1        x1  \
# 0             0      0_0    COMPLETED            Manual  50.487485  0.526302
# 1             1      1_0    COMPLETED            Manual  50.487485  0.628629
# 2             2      2_0    COMPLETED            Manual  50.487485  0.397679
# 3             3      3_0    COMPLETED            Manual  50.487485  0.452311
# 4             4      4_0    COMPLETED            Manual  50.487485  0.576961
# 5             5      5_0    COMPLETED            Manual  50.487485  0.480570
# 6             6      6_0    COMPLETED            Manual  50.487485  0.348583
# 7             7      7_0    COMPLETED            Manual  50.487485  0.383995
# 8             8      8_0    COMPLETED            Manual  50.487485  0.508613
# 9             9      9_0    COMPLETED            Manual  50.487485  0.590711
# 10           10     10_0    COMPLETED            Manual  50.487485  0.458779
# 11           11     11_0    COMPLETED            Manual  50.487485  0.412818
# 12           12     12_0    COMPLETED            Manual  50.487485  0.639286
# 13           13     13_0    COMPLETED            Manual  50.487485  0.563102
# 14           14     14_0    COMPLETED            Manual  50.487485  0.332120
# 15           15     15_0    COMPLETED            Manual  50.487485  0.305166
# 16           16     16_0    COMPLETED            Manual  50.487485  0.301661
# 17           17     17_0    COMPLETED            Manual  50.487485  0.300598
# 18           18     18_0    COMPLETED            Manual  50.487485  0.645058
# 19           19     19_0    COMPLETED            Manual  50.487485  0.649286
#
#           x2        x3
# 0   0.999266  0.600101
# 1   0.990188  0.764140
# 2   0.996250  0.509904
# 3   0.991732  0.649030
# 4   0.995379  0.802816
# 5   0.993564  0.562814
# 6   0.997189  0.715015
# 7   0.990566  0.573835
# 8   0.996630  0.726008
# 9   0.992388  0.689234
# 10  0.998432  0.842997
# 11  0.994396  0.778125
# 12  0.998024  0.523909
# 13  0.991354  0.892720
# 14  0.994999  0.636922
# 15  0.990373  0.899493
# 16  0.993006  0.519949
# 17  0.998907  0.797669
# 18  0.990945  0.614729
# 19  0.993981  0.865395
