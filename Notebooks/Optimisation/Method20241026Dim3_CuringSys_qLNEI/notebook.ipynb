# %% [markdown]
# # Optimising Unknown Curing System: 'Method20241026Dim3'
#
# Settings:
# * Space-Filling Technique: Quasirandom (1 * 27)
# * Sequential Technique: Ax (6 * 1)
# * Acquisition Function: qLNEI

# %% [markdown]
# # Nødvendig Bestanddel:

# %%
from ConfigFile import OptimisationSetup_class
from ExperimentalMethods import ExperimentalMethods_class

# %%
# Instantiate the optimisation configuration class object.
OptimisationSetup_obj = OptimisationSetup_class()
# Instantiate the experimental methods class object.
ExperimentalMethods_obj = ExperimentalMethods_class()

# %%
# Use the initialiser function to import the current experiment or begin a new one.
AxClient_obj = ExperimentalMethods_obj.ExperimentInitialiser_func(OptimisationSetup_obj)
# Out:
# [INFO 11-11 12:03:44] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [INFO 11-11 12:03:44] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='x1', parameter_type=FLOAT, range=[0.3, 0.65]), RangeParameter(name='x2', parameter_type=FLOAT, range=[0.99, 0.9995]), RangeParameter(name='x3', parameter_type=FLOAT, range=[0.5, 0.9])], parameter_constraints=[]).
# [INFO 11-11 12:03:44] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241026Dim3_CuringSys_qLNEI/AxExperiment.json`.
# A new experiment has been created and initialised.

# %%
df = AxClient_obj.get_trials_data_frame()
df
# Out:
# Empty DataFrame
# Columns: [mean, arm_name, metric_name, sem]
# Index: []

# %% [markdown]
# # Stykke 0 - Plot

# %%
from PlottingMethods import PlottingMethods_class
Plotter_obj = PlottingMethods_class()
Plotter_obj.InteractiveSamplesOverviewPlot(AxClient_obj,OptimisationSetup_obj)
# x1 = 30% UP - 65% UP (UP:DeI)
# x2 = 99% - 99.95% UPR1 (UPR1:DMA)
# x3 = 50% - 90% AUPR1 (AUPR1:I1)
# Out:
# 3D Interactive Plot
# interactive(children=(IntSlider(value=25, description='Elevation', max=90, min=-90, step=5), IntSlider(value=5…

# %%
TypeOfJob_str = "mean"
Plotter_obj.InteractiveMeanFunctionPlot(AxClient_obj,OptimisationSetup_obj,TypeOfJob_str)

# %%
TypeOfJob_str = "covariance"
Plotter_obj.InteractiveMeanFunctionPlot(AxClient_obj,OptimisationSetup_obj,TypeOfJob_str)

# %%
TypeOfJob_str = "acquisition"
Plotter_obj.InteractiveMeanFunctionPlot(AxClient_obj,OptimisationSetup_obj,TypeOfJob_str)

# %% [markdown]
# # Stykke 1 - Begyndelsen

# %%
# Initiate the current trials.
ExperimentalMethods_obj.TrialsStartor_func(AxClient_obj,OptimisationSetup_obj)
df = AxClient_obj.get_trials_data_frame()
df
# Out:
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.342625, 'x2': 0.991037, 'x3': 0.570169}] as trial 0.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.515716, 'x2': 0.997623, 'x3': 0.721944}] as trial 1.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.626712, 'x2': 0.993105, 'x3': 0.641714}] as trial 2.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.421044, 'x2': 0.996759, 'x3': 0.867729}] as trial 3.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.453803, 'x2': 0.99456, 'x3': 0.804148}] as trial 4.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.547736, 'x2': 0.990218, 'x3': 0.841449}] as trial 5.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.304508, 'x2': 0.998999, 'x3': 0.66922}] as trial 6.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.313702, 'x2': 0.992422, 'x3': 0.830821}] as trial 7.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.544448, 'x2': 0.996073, 'x3': 0.679046}] as trial 8.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.59629, 'x2': 0.991555, 'x3': 0.76054}] as trial 9.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.451277, 'x2': 0.998144, 'x3': 0.534525}] as trial 10.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.388248, 'x2': 0.99082, 'x3': 0.59729}] as trial 11.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.483635, 'x2': 0.993803, 'x3': 0.56041}] as trial 12.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.368799, 'x2': 0.99526, 'x3': 0.732638}] as trial 13.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.361448, 'x2': 0.993617, 'x3': 0.688547}] as trial 14.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.496887, 'x2': 0.995044, 'x3': 0.820065}] as trial 15.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.646273, 'x2': 0.990505, 'x3': 0.523363}] as trial 16.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.401477, 'x2': 0.999358, 'x3': 0.769633}] as trial 17.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.606686, 'x2': 0.99857, 'x3': 0.608043}] as trial 18.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.528174, 'x2': 0.992748, 'x3': 0.743802}] as trial 19.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.324075, 'x2': 0.996469, 'x3': 0.551316}] as trial 20.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.561062, 'x2': 0.998674, 'x3': 0.581371}] as trial 21.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.580419, 'x2': 0.994134, 'x3': 0.878497}] as trial 22.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.467152, 'x2': 0.995563, 'x3': 0.632226}] as trial 23.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.636987, 'x2': 0.997074, 'x3': 0.792945}] as trial 24.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.499506, 'x2': 0.991252, 'x3': 0.658453}] as trial 25.
# [INFO 11-11 12:03:48] ax.core.experiment: Attached custom parameterizations [{'x1': 0.352924, 'x2': 0.997809, 'x3': 0.850939}] as trial 26.
# [INFO 11-11 12:03:48] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241026Dim3_CuringSys_qLNEI/AxExperiment.json`.
# [WARNING 11-11 12:03:48] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-11 12:03:48] ax.service.utils.report_utils: No results present for the specified metrics `[Metric('t1')]`. Returning arm parameters and metadata only.
# No previous or current trials detected - initialising prior-forming trials.
# [[0.34262477 0.51571568 0.62671168 0.42104414 0.45380267 0.54773585
#   0.30450823 0.31370238 0.54444841 0.59628965 0.45127651 0.38824816
#   0.48363483 0.36879892 0.36144816 0.49688674 0.64627346 0.401477
#   0.60668582 0.52817417 0.32407546 0.56106207 0.58041903 0.46715196
#   0.6369874  0.49950556 0.35292355]
#  [0.99103697 0.99762341 0.99310509 0.99675861 0.99455996 0.99021833
#   0.99899934 0.99242223 0.99607263 0.99155451 0.99814407 0.99082039
#   0.99380261 0.99525965 0.99361745 0.99504414 0.99050456 0.99935792
#   0.99856964 0.9927478  0.99646866 0.99867381 0.99413436 0.99556292
#   0.99707448 0.99125244 0.99780852]
#  [0.57016883 0.72194392 0.64171376 0.86772897 0.8041482  0.84144866
#   0.66922005 0.83082056 0.67904587 0.76053958 0.53452479 0.59728982
#   0.5604096  0.7326378  0.68854737 0.82006464 0.52336277 0.76963333
#   0.60804306 0.74380208 0.55131646 0.58137132 0.87849714 0.63222616
#   0.79294509 0.65845291 0.85093894]]
#     trial_index arm_name trial_status generation_method        x1        x2  \
# 0             0      0_0      RUNNING            Manual  0.342625  0.991037
# 1             1      1_0      RUNNING            Manual  0.515716  0.997623
# 2             2      2_0      RUNNING            Manual  0.626712  0.993105
# 3             3      3_0      RUNNING            Manual  0.421044  0.996759
# 4             4      4_0      RUNNING            Manual  0.453803  0.994560
# 5             5      5_0      RUNNING            Manual  0.547736  0.990218
# 6             6      6_0      RUNNING            Manual  0.304508  0.998999
# 7             7      7_0      RUNNING            Manual  0.313702  0.992422
# 8             8      8_0      RUNNING            Manual  0.544448  0.996073
# 9             9      9_0      RUNNING            Manual  0.596290  0.991555
# 10           10     10_0      RUNNING            Manual  0.451277  0.998144
# 11           11     11_0      RUNNING            Manual  0.388248  0.990820
# 12           12     12_0      RUNNING            Manual  0.483635  0.993803
# 13           13     13_0      RUNNING            Manual  0.368799  0.995260
# 14           14     14_0      RUNNING            Manual  0.361448  0.993617
# 15           15     15_0      RUNNING            Manual  0.496887  0.995044
# 16           16     16_0      RUNNING            Manual  0.646273  0.990505
# 17           17     17_0      RUNNING            Manual  0.401477  0.999358
# 18           18     18_0      RUNNING            Manual  0.606686  0.998570
# 19           19     19_0      RUNNING            Manual  0.528174  0.992748
# 20           20     20_0      RUNNING            Manual  0.324075  0.996469
# 21           21     21_0      RUNNING            Manual  0.561062  0.998674
# 22           22     22_0      RUNNING            Manual  0.580419  0.994134
# 23           23     23_0      RUNNING            Manual  0.467152  0.995563
# 24           24     24_0      RUNNING            Manual  0.636987  0.997074
# 25           25     25_0      RUNNING            Manual  0.499506  0.991252
# 26           26     26_0      RUNNING            Manual  0.352924  0.997809
#
#           x3
# 0   0.570169
# 1   0.721944
# 2   0.641714
# 3   0.867729
# 4   0.804148
# 5   0.841449
# 6   0.669220
# 7   0.830821
# 8   0.679046
# 9   0.760540
# 10  0.534525
# 11  0.597290
# 12  0.560410
# 13  0.732638
# 14  0.688547
# 15  0.820065
# 16  0.523363
# 17  0.769633
# 18  0.608043
# 19  0.743802
# 20  0.551316
# 21  0.581371
# 22  0.878497
# 23  0.632226
# 24  0.792945
# 25  0.658453
# 26  0.850939

# %%
# Carry out the experimentation associated with the current trials.
ExperimentalMethods_obj.TrialsExecutor_func(AxClient_obj,OptimisationSetup_obj)
# Out:
# [WARNING 11-11 12:03:49] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-11 12:03:49] ax.service.utils.report_utils: No results present for the specified metrics `[Metric('t1')]`. Returning arm parameters and metadata only.
# [WARNING 11-11 12:03:49] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-11 12:03:49] ax.service.utils.report_utils: No results present for the specified metrics `[Metric('t1')]`. Returning arm parameters and metadata only.
# Trials are running. - Searching for parameterisation backup file
# No backup file available!
# Running trials have not executed by the operator - executing...
# Retrieving trials.
#
# ===== Preliminary Setup =====
# Pre-Heat the Oven to 80oC.
# Continue? (y)
# 		Input:  y
#
# ===== Initial Pouring of StockUPR1 =====
# Use a P10mL pipette set to 2 ml to transfer StockUPR1 to 27 mould gaps.
#
# -----Trial 0-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 1-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 2-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 3-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 4-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 5-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 6-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 7-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 8-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 9-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 10-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 11-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 12-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 13-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 14-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 15-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 16-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 17-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 18-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 19-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 20-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 21-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 22-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 23-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 24-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 25-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# -----Trial 26-----
# Mass of StockUPR1 transferred? (g)
# 		Input:  2.0
#
# ===== Mixing UPR1 from StockUPR1 & DeI =====
#
# -----Trial 0-----
# Add 2.007 g DeI
# Use P10mL equipped with D10mL.
# Set to 2.131 ml and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 1-----
# Add 0.662 g DeI
# Use P200 equipped with D200.
# Set to 170.569 ul and make 4 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 2-----
# Add 0.19 g DeI
# Use P200 equipped with D200.
# Set to 196.451 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 3-----
# Add 1.26 g DeI
# Use P10mL equipped with D10mL.
# Set to 1.352 ml and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 4-----
# Add 1.025 g DeI
# Use P200 equipped with D200.
# Set to 211.558 ul and make 5 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 5-----
# Add 0.506 g DeI
# Use P200 equipped with D200.
# Set to 173.976 ul and make 3 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 6-----
# Add 2.508 g DeI
# Use P10mL equipped with D10mL.
# Set to 2.654 ml and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 7-----
# Add 2.376 g DeI
# Use P10mL equipped with D10mL.
# Set to 2.516 ml and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 8-----
# Add 0.521 g DeI
# Use P200 equipped with D200.
# Set to 179.205 ul and make 3 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 9-----
# Add 0.302 g DeI
# Use P200 equipped with D200.
# Set to 155.668 ul and make 2 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 10-----
# Add 1.042 g DeI
# Use P10mL equipped with D10mL.
# Set to 1.124 ml and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 11-----
# Add 1.536 g DeI
# Use P10mL equipped with D10mL.
# Set to 1.639 ml and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 12-----
# Add 0.838 g DeI
# Use P200 equipped with D200.
# Set to 172.871 ul and make 5 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 13-----
# Add 1.722 g DeI
# Use P10mL equipped with D10mL.
# Set to 1.834 ml and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 14-----
# Add 1.798 g DeI
# Use P10mL equipped with D10mL.
# Set to 1.913 ml and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 15-----
# Add 0.763 g DeI
# Use P200 equipped with D200.
# Set to 196.711 ul and make 4 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 16-----
# Add 0.124 g DeI
# Use P200 equipped with D200.
# Set to 127.719 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 17-----
# Add 1.419 g DeI
# Use P10mL equipped with D10mL.
# Set to 1.518 ml and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 18-----
# Add 0.263 g DeI
# Use P200 equipped with D200.
# Set to 135.219 ul and make 2 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 19-----
# Add 0.599 g DeI
# Use P200 equipped with D200.
# Set to 206.051 ul and make 3 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 20-----
# Add 2.236 g DeI
# Use P10mL equipped with D10mL.
# Set to 2.37 ml and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 21-----
# Add 0.447 g DeI
# Use P200 equipped with D200.
# Set to 153.406 ul and make 3 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 22-----
# Add 0.365 g DeI
# Use P200 equipped with D200.
# Set to 188.296 ul and make 2 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 23-----
# Add 0.939 g DeI
# Use P200 equipped with D200.
# Set to 193.635 ul and make 5 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 24-----
# Add 0.155 g DeI
# Use P200 equipped with D200.
# Set to 159.82 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 25-----
# Add 0.748 g DeI
# Use P200 equipped with D200.
# Set to 192.957 ul and make 4 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 26-----
# Add 1.89 g DeI
# Use P10mL equipped with D10mL.
# Set to 2.009 ml and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# ===== Mixing AUPR1 from UPR1 & DMA =====
#
# -----Trial 0-----
# Add 0.0362 g DMA
# Use P200 equipped with D200.
# Set to 37.411 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 1-----
# Add 0.0063 g DMA
# Use P20 equipped with D200.
# Set to 6.417 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 2-----
# Add 0.0152 g DMA
# Use P20 equipped with D200.
# Set to 15.654 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 3-----
# Add 0.0106 g DMA
# Use P20 equipped with D200.
# Set to 10.856 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 4-----
# Add 0.0165 g DMA
# Use P20 equipped with D200.
# Set to 17.049 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 5-----
# Add 0.0248 g DMA
# Use P200 equipped with D200.
# Set to 25.318 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 6-----
# Add 0.0045 g DMA
# Use P20 equipped with D200.
# Set to 4.514 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 7-----
# Add 0.0334 g DMA
# Use P200 equipped with D200.
# Set to 34.437 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 8-----
# Add 0.0099 g DMA
# Use P20 equipped with D200.
# Set to 10.168 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 9-----
# Add 0.0196 g DMA
# Use P200 equipped with D200.
# Set to 19.893 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 10-----
# Add 0.0057 g DMA
# Use P20 equipped with D200.
# Set to 5.703 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 11-----
# Add 0.0328 g DMA
# Use P200 equipped with D200.
# Set to 33.747 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 12-----
# Add 0.0177 g DMA
# Use P20 equipped with D200.
# Set to 18.252 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 13-----
# Add 0.0177 g DMA
# Use P20 equipped with D200.
# Set to 18.281 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 14-----
# Add 0.0244 g DMA
# Use P200 equipped with D200.
# Set to 24.937 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 15-----
# Add 0.0138 g DMA
# Use P20 equipped with D200.
# Set to 14.146 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 16-----
# Add 0.0204 g DMA
# Use P200 equipped with D200.
# Set to 20.688 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 17-----
# Add 0.0022 g DMA
# Use P20 equipped with D200.
# Set to 2.099 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 18-----
# Add 0.0032 g DMA
# Use P20 equipped with D200.
# Set to 3.187 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 19-----
# Add 0.019 g DMA
# Use P20 equipped with D200.
# Set to 19.592 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 20-----
# Add 0.015 g DMA
# Use P20 equipped with D200.
# Set to 15.45 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 21-----
# Add 0.0032 g DMA
# Use P20 equipped with D200.
# Set to 3.195 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 22-----
# Add 0.014 g DMA
# Use P20 equipped with D200.
# Set to 14.349 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 23-----
# Add 0.0131 g DMA
# Use P20 equipped with D200.
# Set to 13.455 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 24-----
# Add 0.0063 g DMA
# Use P20 equipped with D200.
# Set to 6.398 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 25-----
# Add 0.0243 g DMA
# Use P200 equipped with D200.
# Set to 24.786 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# -----Trial 26-----
# Add 0.0085 g DMA
# Use P20 equipped with D200.
# Set to 8.71 ul and make 1 transfer(s).
# Continue? (y)
# 		Input:  y
#
# ===== Mixing IAUPR1 from AUPR1 & I1 =====
#
# -----Trial 0-----
# Add 3.05 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 1-----
# Add 1.03 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 2-----
# Add 1.23 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 3-----
# Add 0.5 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 4-----
# Add 0.74 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 5-----
# Add 0.48 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 6-----
# Add 2.23 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 7-----
# Add 0.9 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 8-----
# Add 1.2 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 9-----
# Add 0.73 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 10-----
# Add 2.65 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 11-----
# Add 2.41 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 12-----
# Add 2.24 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 13-----
# Add 1.36 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 14-----
# Add 1.73 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 15-----
# Add 0.61 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 16-----
# Add 1.95 g I1
# Continue? (y)
# Please confirm. (y)
# 		Input:  y
#
# -----Trial 17-----
# Add 1.02 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 18-----
# Add 1.46 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 19-----
# Add 0.9 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 20-----
# Add 3.46 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 21-----
# Add 1.76 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 22-----
# Add 0.33 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 23-----
# Add 1.72 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 24-----
# Add 0.56 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 25-----
# Add 1.44 g I1
# Continue? (y)
# 		Input:  y
#
# -----Trial 26-----
# Add 0.68 g I1
# Continue? (y)
# 		Input:  y
#
# ===== Curing Regime =====
# Stage1: 180 mins @ 80 oC
# Stage2: 60 mins @ 120 oC

# %% [markdown]
# # Stykke 2 - Enden

# %%
# Complete the current trials.
ExperimentalMethods_obj.TrialsCompletor_func(AxClient_obj,OptimisationSetup_obj)

# %%
df = AxClient_obj.get_trials_data_frame()
df
