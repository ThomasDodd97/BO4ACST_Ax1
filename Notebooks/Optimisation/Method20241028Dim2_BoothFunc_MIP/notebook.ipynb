# %% [markdown]
# # Optimising Booth Test Function: 'Method20241028Dim2'
#
# Settings:
# * Space-Filling Technique: Grid (1 * 8)
# * Sequential Technique: MIP (16 * 1)

# %%
import os
import numpy as np
from ConfigFile import OptimisationSetup_class
from ExperimentalMethods import ExperimentalMethods_class
# Instantiate the optimisation configuration class object.
OptimisationSetup_obj = OptimisationSetup_class()
# Instantiate the experimental methods class object.
ExperimentalMethods_obj = ExperimentalMethods_class()

# %%
# Using the McIntersiteProj
attempts = 10
t1Best_arr = np.empty(0)
for attempt in range(attempts):
    t1Min_arr = np.empty(0)
    AxClient_obj = ExperimentalMethods_obj.ExperimentInitialiser_func(OptimisationSetup_obj)
    for round in range(OptimisationSetup_obj.NoOfIterations_int):
        ExperimentalMethods_obj.TrialsStartor_func(AxClient_obj,OptimisationSetup_obj)
        ExperimentalMethods_obj.TrialsCompletor_func(AxClient_obj,OptimisationSetup_obj)
        df = AxClient_obj.get_trials_data_frame()
        print(df)
        t1_arr = np.array(df["t1"])
        t1Min_flt = np.min(t1_arr)
        t1Min_arr = np.append(arr=t1Min_arr,values=t1Min_flt)
    os.remove(OptimisationSetup_obj.ExperimentFilePath_str)
    Bestt1_flt = t1Min_arr[-1]
    t1Best_arr = np.append(arr=t1Best_arr,values=Bestt1_flt)
# Out:
# [INFO 11-04 13:18:30] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [INFO 11-04 13:18:30] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='x1', parameter_type=FLOAT, range=[-10.0, 10.0]), RangeParameter(name='x2', parameter_type=FLOAT, range=[-10.0, 10.0])], parameter_constraints=[]).
# [INFO 11-04 13:18:30] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [INFO 11-04 13:18:30] ax.core.experiment: Attached custom parameterizations [{'x1': -10.0, 'x2': -10.0}] as trial 0.
# [INFO 11-04 13:18:30] ax.core.experiment: Attached custom parameterizations [{'x1': 0.0, 'x2': -10.0}] as trial 1.
# [INFO 11-04 13:18:30] ax.core.experiment: Attached custom parameterizations [{'x1': 10.0, 'x2': -10.0}] as trial 2.
# [INFO 11-04 13:18:30] ax.core.experiment: Attached custom parameterizations [{'x1': -10.0, 'x2': 0.0}] as trial 3.
# [INFO 11-04 13:18:30] ax.core.experiment: Attached custom parameterizations [{'x1': 0.0, 'x2': 0.0}] as trial 4.
# [INFO 11-04 13:18:30] ax.core.experiment: Attached custom parameterizations [{'x1': 10.0, 'x2': 0.0}] as trial 5.
# [INFO 11-04 13:18:30] ax.core.experiment: Attached custom parameterizations [{'x1': -10.0, 'x2': 10.0}] as trial 6.
# [INFO 11-04 13:18:30] ax.core.experiment: Attached custom parameterizations [{'x1': 0.0, 'x2': 10.0}] as trial 7.
# [INFO 11-04 13:18:30] ax.core.experiment: Attached custom parameterizations [{'x1': 10.0, 'x2': 10.0}] as trial 8.
# [INFO 11-04 13:18:30] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:18:30] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:18:30] ax.service.utils.report_utils: No results present for the specified metrics `[Metric('t1')]`. Returning arm parameters and metadata only.
# [WARNING 11-04 13:18:30] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:18:30] ax.service.utils.report_utils: No results present for the specified metrics `[Metric('t1')]`. Returning arm parameters and metadata only.
# [INFO 11-04 13:18:30] ax.service.ax_client: Completed trial 0 with data: {'t1': (2594.0, None)}.
# [INFO 11-04 13:18:30] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [INFO 11-04 13:18:30] ax.service.ax_client: Completed trial 1 with data: {'t1': (954.0, None)}.
# [INFO 11-04 13:18:30] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [INFO 11-04 13:18:30] ax.service.ax_client: Completed trial 2 with data: {'t1': (314.0, None)}.
# [INFO 11-04 13:18:30] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [INFO 11-04 13:18:30] ax.service.ax_client: Completed trial 3 with data: {'t1': (914.0, None)}.
# [INFO 11-04 13:18:30] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [INFO 11-04 13:18:30] ax.service.ax_client: Completed trial 4 with data: {'t1': (74.0, None)}.
# [INFO 11-04 13:18:30] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [INFO 11-04 13:18:30] ax.service.ax_client: Completed trial 5 with data: {'t1': (234.0, None)}.
# [INFO 11-04 13:18:30] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [INFO 11-04 13:18:30] ax.service.ax_client: Completed trial 6 with data: {'t1': (234.0, None)}.
# [INFO 11-04 13:18:30] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [INFO 11-04 13:18:30] ax.service.ax_client: Completed trial 7 with data: {'t1': (194.0, None)}.
# [INFO 11-04 13:18:30] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [INFO 11-04 13:18:30] ax.service.ax_client: Completed trial 8 with data: {'t1': (1154.0, None)}.
# [INFO 11-04 13:18:30] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:18:30] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:30] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:30] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# A new experiment has been created and initialised.
# No previous or current trials detected - initialising prior-forming trials.
# Samples gridded = 9
# [-10. -10.]
# [  0. -10.]
# [ 10. -10.]
# [-10.   0.]
# [0. 0.]
# [10.  0.]
# [-10.  10.]
# [ 0. 10.]
# [10. 10.]
#    trial_index arm_name trial_status generation_method      t1    x1    x2
# 0            0      0_0    COMPLETED            Manual  2594.0 -10.0 -10.0
# 1            1      1_0    COMPLETED            Manual   954.0   0.0 -10.0
# 2            2      2_0    COMPLETED            Manual   314.0  10.0 -10.0
# 3            3      3_0    COMPLETED            Manual   914.0 -10.0   0.0
# 4            4      4_0    COMPLETED            Manual    74.0   0.0   0.0
# 5            5      5_0    COMPLETED            Manual   234.0  10.0   0.0
# 6            6      6_0    COMPLETED            Manual   234.0 -10.0  10.0
# 7            7      7_0    COMPLETED            Manual   194.0   0.0  10.0
# 8            8      8_0    COMPLETED            Manual  1154.0  10.0  10.0
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:18:32] ax.core.experiment: Attached custom parameterizations [{'x1': 5.008388, 'x2': -5.010102}] as trial 9.
# [INFO 11-04 13:18:32] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:32] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:32] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:18:32] ax.service.ax_client: Completed trial 9 with data: {'t1': (144.283766, None)}.
# [INFO 11-04 13:18:32] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:18:32] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:32] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:32] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [ 5.00838805 -5.01010199]
#    trial_index arm_name trial_status generation_method           t1  \
# 0            0      0_0    COMPLETED            Manual  2594.000000
# 1            1      1_0    COMPLETED            Manual   954.000000
# 2            2      2_0    COMPLETED            Manual   314.000000
# 3            3      3_0    COMPLETED            Manual   914.000000
# 4            4      4_0    COMPLETED            Manual    74.000000
# 5            5      5_0    COMPLETED            Manual   234.000000
# 6            6      6_0    COMPLETED            Manual   234.000000
# 7            7      7_0    COMPLETED            Manual   194.000000
# 8            8      8_0    COMPLETED            Manual  1154.000000
# 9            9      9_0    COMPLETED            Manual   144.283766
#
#           x1         x2
# 0 -10.000000 -10.000000
# 1   0.000000 -10.000000
# 2  10.000000 -10.000000
# 3 -10.000000   0.000000
# 4   0.000000   0.000000
# 5  10.000000   0.000000
# 6 -10.000000  10.000000
# 7   0.000000  10.000000
# 8  10.000000  10.000000
# 9   5.008388  -5.010102
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:18:33] ax.core.experiment: Attached custom parameterizations [{'x1': -5.139785, 'x2': 5.125778}] as trial 10.
# [INFO 11-04 13:18:33] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:33] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:33] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:18:33] ax.service.ax_client: Completed trial 10 with data: {'t1': (106.664881, None)}.
# [INFO 11-04 13:18:33] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:18:33] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:33] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:33] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [-5.13978462  5.12577812]
#     trial_index arm_name trial_status generation_method           t1  \
# 0             0      0_0    COMPLETED            Manual  2594.000000
# 1             1      1_0    COMPLETED            Manual   954.000000
# 2             2      2_0    COMPLETED            Manual   314.000000
# 3             3      3_0    COMPLETED            Manual   914.000000
# 4             4      4_0    COMPLETED            Manual    74.000000
# 5             5      5_0    COMPLETED            Manual   234.000000
# 6             6      6_0    COMPLETED            Manual   234.000000
# 7             7      7_0    COMPLETED            Manual   194.000000
# 8             8      8_0    COMPLETED            Manual  1154.000000
# 9             9      9_0    COMPLETED            Manual   144.283766
# 10           10     10_0    COMPLETED            Manual   106.664881
#
#            x1         x2
# 0  -10.000000 -10.000000
# 1    0.000000 -10.000000
# 2   10.000000 -10.000000
# 3  -10.000000   0.000000
# 4    0.000000   0.000000
# 5   10.000000   0.000000
# 6  -10.000000  10.000000
# 7    0.000000  10.000000
# 8   10.000000  10.000000
# 9    5.008388  -5.010102
# 10  -5.139785   5.125778
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:18:35] ax.core.experiment: Attached custom parameterizations [{'x1': -2.569313, 'x2': 2.539676}] as trial 11.
# [INFO 11-04 13:18:35] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:35] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:35] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:18:35] ax.service.ax_client: Completed trial 11 with data: {'t1': (77.903815, None)}.
# [INFO 11-04 13:18:35] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:18:35] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:35] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:35] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [-2.56931334  2.53967566]
#     trial_index arm_name trial_status generation_method           t1  \
# 0             0      0_0    COMPLETED            Manual  2594.000000
# 1             1      1_0    COMPLETED            Manual   954.000000
# 2             2      2_0    COMPLETED            Manual   314.000000
# 3             3      3_0    COMPLETED            Manual   914.000000
# 4             4      4_0    COMPLETED            Manual    74.000000
# 5             5      5_0    COMPLETED            Manual   234.000000
# 6             6      6_0    COMPLETED            Manual   234.000000
# 7             7      7_0    COMPLETED            Manual   194.000000
# 8             8      8_0    COMPLETED            Manual  1154.000000
# 9             9      9_0    COMPLETED            Manual   144.283766
# 10           10     10_0    COMPLETED            Manual   106.664881
# 11           11     11_0    COMPLETED            Manual    77.903815
#
#            x1         x2
# 0  -10.000000 -10.000000
# 1    0.000000 -10.000000
# 2   10.000000 -10.000000
# 3  -10.000000   0.000000
# 4    0.000000   0.000000
# 5   10.000000   0.000000
# 6  -10.000000  10.000000
# 7    0.000000  10.000000
# 8   10.000000  10.000000
# 9    5.008388  -5.010102
# 10  -5.139785   5.125778
# 11  -2.569313   2.539676
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:18:37] ax.core.experiment: Attached custom parameterizations [{'x1': 2.434446, 'x2': -2.462556}] as trial 12.
# [INFO 11-04 13:18:37] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:37] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:37] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:18:37] ax.service.ax_client: Completed trial 12 with data: {'t1': (96.799838, None)}.
# [INFO 11-04 13:18:37] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:18:37] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:37] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:37] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [ 2.43444605 -2.46255612]
#     trial_index arm_name trial_status generation_method           t1  \
# 0             0      0_0    COMPLETED            Manual  2594.000000
# 1             1      1_0    COMPLETED            Manual   954.000000
# 2             2      2_0    COMPLETED            Manual   314.000000
# 3             3      3_0    COMPLETED            Manual   914.000000
# 4             4      4_0    COMPLETED            Manual    74.000000
# 5             5      5_0    COMPLETED            Manual   234.000000
# 6             6      6_0    COMPLETED            Manual   234.000000
# 7             7      7_0    COMPLETED            Manual   194.000000
# 8             8      8_0    COMPLETED            Manual  1154.000000
# 9             9      9_0    COMPLETED            Manual   144.283766
# 10           10     10_0    COMPLETED            Manual   106.664881
# 11           11     11_0    COMPLETED            Manual    77.903815
# 12           12     12_0    COMPLETED            Manual    96.799838
#
#            x1         x2
# 0  -10.000000 -10.000000
# 1    0.000000 -10.000000
# 2   10.000000 -10.000000
# 3  -10.000000   0.000000
# 4    0.000000   0.000000
# 5   10.000000   0.000000
# 6  -10.000000  10.000000
# 7    0.000000  10.000000
# 8   10.000000  10.000000
# 9    5.008388  -5.010102
# 10  -5.139785   5.125778
# 11  -2.569313   2.539676
# 12   2.434446  -2.462556
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:18:39] ax.core.experiment: Attached custom parameterizations [{'x1': -7.549616, 'x2': 7.611593}] as trial 13.
# [INFO 11-04 13:18:39] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:39] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:39] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:18:39] ax.service.ax_client: Completed trial 13 with data: {'t1': (156.394816, None)}.
# [INFO 11-04 13:18:39] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:18:39] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:39] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:39] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [-7.5496158   7.61159293]
#     trial_index arm_name trial_status generation_method           t1  \
# 0             0      0_0    COMPLETED            Manual  2594.000000
# 1             1      1_0    COMPLETED            Manual   954.000000
# 2             2      2_0    COMPLETED            Manual   314.000000
# 3             3      3_0    COMPLETED            Manual   914.000000
# 4             4      4_0    COMPLETED            Manual    74.000000
# 5             5      5_0    COMPLETED            Manual   234.000000
# 6             6      6_0    COMPLETED            Manual   234.000000
# 7             7      7_0    COMPLETED            Manual   194.000000
# 8             8      8_0    COMPLETED            Manual  1154.000000
# 9             9      9_0    COMPLETED            Manual   144.283766
# 10           10     10_0    COMPLETED            Manual   106.664881
# 11           11     11_0    COMPLETED            Manual    77.903815
# 12           12     12_0    COMPLETED            Manual    96.799838
# 13           13     13_0    COMPLETED            Manual   156.394816
#
#            x1         x2
# 0  -10.000000 -10.000000
# 1    0.000000 -10.000000
# 2   10.000000 -10.000000
# 3  -10.000000   0.000000
# 4    0.000000   0.000000
# 5   10.000000   0.000000
# 6  -10.000000  10.000000
# 7    0.000000  10.000000
# 8   10.000000  10.000000
# 9    5.008388  -5.010102
# 10  -5.139785   5.125778
# 11  -2.569313   2.539676
# 12   2.434446  -2.462556
# 13  -7.549616   7.611593
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:18:41] ax.core.experiment: Attached custom parameterizations [{'x1': 7.47788, 'x2': -7.411117}] as trial 14.
# [INFO 11-04 13:18:41] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:41] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:41] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:18:41] ax.service.ax_client: Completed trial 14 with data: {'t1': (212.235726, None)}.
# [INFO 11-04 13:18:41] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:18:41] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:41] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:41] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [ 7.47787972 -7.41111741]
#     trial_index arm_name trial_status generation_method           t1  \
# 0             0      0_0    COMPLETED            Manual  2594.000000
# 1             1      1_0    COMPLETED            Manual   954.000000
# 2             2      2_0    COMPLETED            Manual   314.000000
# 3             3      3_0    COMPLETED            Manual   914.000000
# 4             4      4_0    COMPLETED            Manual    74.000000
# 5             5      5_0    COMPLETED            Manual   234.000000
# 6             6      6_0    COMPLETED            Manual   234.000000
# 7             7      7_0    COMPLETED            Manual   194.000000
# 8             8      8_0    COMPLETED            Manual  1154.000000
# 9             9      9_0    COMPLETED            Manual   144.283766
# 10           10     10_0    COMPLETED            Manual   106.664881
# 11           11     11_0    COMPLETED            Manual    77.903815
# 12           12     12_0    COMPLETED            Manual    96.799838
# 13           13     13_0    COMPLETED            Manual   156.394816
# 14           14     14_0    COMPLETED            Manual   212.235726
#
#            x1         x2
# 0  -10.000000 -10.000000
# 1    0.000000 -10.000000
# 2   10.000000 -10.000000
# 3  -10.000000   0.000000
# 4    0.000000   0.000000
# 5   10.000000   0.000000
# 6  -10.000000  10.000000
# 7    0.000000  10.000000
# 8   10.000000  10.000000
# 9    5.008388  -5.010102
# 10  -5.139785   5.125778
# 11  -2.569313   2.539676
# 12   2.434446  -2.462556
# 13  -7.549616   7.611593
# 14   7.477880  -7.411117
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:18:44] ax.core.experiment: Attached custom parameterizations [{'x1': 6.229546, 'x2': 3.904894}] as trial 15.
# [INFO 11-04 13:18:44] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:44] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:44] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:18:44] ax.service.ax_client: Completed trial 15 with data: {'t1': (178.692409, None)}.
# [INFO 11-04 13:18:44] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:18:44] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:44] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:44] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [6.22954637 3.90489374]
#     trial_index arm_name trial_status generation_method           t1  \
# 0             0      0_0    COMPLETED            Manual  2594.000000
# 1             1      1_0    COMPLETED            Manual   954.000000
# 2             2      2_0    COMPLETED            Manual   314.000000
# 3             3      3_0    COMPLETED            Manual   914.000000
# 4             4      4_0    COMPLETED            Manual    74.000000
# 5             5      5_0    COMPLETED            Manual   234.000000
# 6             6      6_0    COMPLETED            Manual   234.000000
# 7             7      7_0    COMPLETED            Manual   194.000000
# 8             8      8_0    COMPLETED            Manual  1154.000000
# 9             9      9_0    COMPLETED            Manual   144.283766
# 10           10     10_0    COMPLETED            Manual   106.664881
# 11           11     11_0    COMPLETED            Manual    77.903815
# 12           12     12_0    COMPLETED            Manual    96.799838
# 13           13     13_0    COMPLETED            Manual   156.394816
# 14           14     14_0    COMPLETED            Manual   212.235726
# 15           15     15_0    COMPLETED            Manual   178.692409
#
#            x1         x2
# 0  -10.000000 -10.000000
# 1    0.000000 -10.000000
# 2   10.000000 -10.000000
# 3  -10.000000   0.000000
# 4    0.000000   0.000000
# 5   10.000000   0.000000
# 6  -10.000000  10.000000
# 7    0.000000  10.000000
# 8   10.000000  10.000000
# 9    5.008388  -5.010102
# 10  -5.139785   5.125778
# 11  -2.569313   2.539676
# 12   2.434446  -2.462556
# 13  -7.549616   7.611593
# 14   7.477880  -7.411117
# 15   6.229546   3.904894
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:18:46] ax.core.experiment: Attached custom parameterizations [{'x1': -3.892278, 'x2': -3.779069}] as trial 16.
# [INFO 11-04 13:18:46] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:46] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:46] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:18:46] ax.service.ax_client: Completed trial 16 with data: {'t1': (614.771521, None)}.
# [INFO 11-04 13:18:46] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:18:46] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:46] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:46] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [-3.89227846 -3.77906853]
#     trial_index arm_name trial_status generation_method           t1  \
# 0             0      0_0    COMPLETED            Manual  2594.000000
# 1             1      1_0    COMPLETED            Manual   954.000000
# 2             2      2_0    COMPLETED            Manual   314.000000
# 3             3      3_0    COMPLETED            Manual   914.000000
# 4             4      4_0    COMPLETED            Manual    74.000000
# 5             5      5_0    COMPLETED            Manual   234.000000
# 6             6      6_0    COMPLETED            Manual   234.000000
# 7             7      7_0    COMPLETED            Manual   194.000000
# 8             8      8_0    COMPLETED            Manual  1154.000000
# 9             9      9_0    COMPLETED            Manual   144.283766
# 10           10     10_0    COMPLETED            Manual   106.664881
# 11           11     11_0    COMPLETED            Manual    77.903815
# 12           12     12_0    COMPLETED            Manual    96.799838
# 13           13     13_0    COMPLETED            Manual   156.394816
# 14           14     14_0    COMPLETED            Manual   212.235726
# 15           15     15_0    COMPLETED            Manual   178.692409
# 16           16     16_0    COMPLETED            Manual   614.771521
#
#            x1         x2
# 0  -10.000000 -10.000000
# 1    0.000000 -10.000000
# 2   10.000000 -10.000000
# 3  -10.000000   0.000000
# 4    0.000000   0.000000
# 5   10.000000   0.000000
# 6  -10.000000  10.000000
# 7    0.000000  10.000000
# 8   10.000000  10.000000
# 9    5.008388  -5.010102
# 10  -5.139785   5.125778
# 11  -2.569313   2.539676
# 12   2.434446  -2.462556
# 13  -7.549616   7.611593
# 14   7.477880  -7.411117
# 15   6.229546   3.904894
# 16  -3.892278  -3.779069
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:18:49] ax.core.experiment: Attached custom parameterizations [{'x1': -1.234204, 'x2': 6.393691}] as trial 17.
# [INFO 11-04 13:18:49] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:49] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:49] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:18:49] ax.service.ax_client: Completed trial 17 with data: {'t1': (21.886454, None)}.
# [INFO 11-04 13:18:49] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:18:49] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:49] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:49] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [-1.23420395  6.39369146]
#     trial_index arm_name trial_status generation_method           t1  \
# 0             0      0_0    COMPLETED            Manual  2594.000000
# 1             1      1_0    COMPLETED            Manual   954.000000
# 2             2      2_0    COMPLETED            Manual   314.000000
# 3             3      3_0    COMPLETED            Manual   914.000000
# 4             4      4_0    COMPLETED            Manual    74.000000
# 5             5      5_0    COMPLETED            Manual   234.000000
# 6             6      6_0    COMPLETED            Manual   234.000000
# 7             7      7_0    COMPLETED            Manual   194.000000
# 8             8      8_0    COMPLETED            Manual  1154.000000
# 9             9      9_0    COMPLETED            Manual   144.283766
# 10           10     10_0    COMPLETED            Manual   106.664881
# 11           11     11_0    COMPLETED            Manual    77.903815
# 12           12     12_0    COMPLETED            Manual    96.799838
# 13           13     13_0    COMPLETED            Manual   156.394816
# 14           14     14_0    COMPLETED            Manual   212.235726
# 15           15     15_0    COMPLETED            Manual   178.692409
# 16           16     16_0    COMPLETED            Manual   614.771521
# 17           17     17_0    COMPLETED            Manual    21.886454
#
#            x1         x2
# 0  -10.000000 -10.000000
# 1    0.000000 -10.000000
# 2   10.000000 -10.000000
# 3  -10.000000   0.000000
# 4    0.000000   0.000000
# 5   10.000000   0.000000
# 6  -10.000000  10.000000
# 7    0.000000  10.000000
# 8   10.000000  10.000000
# 9    5.008388  -5.010102
# 10  -5.139785   5.125778
# 11  -2.569313   2.539676
# 12   2.434446  -2.462556
# 13  -7.549616   7.611593
# 14   7.477880  -7.411117
# 15   6.229546   3.904894
# 16  -3.892278  -3.779069
# 17  -1.234204   6.393691
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:18:52] ax.core.experiment: Attached custom parameterizations [{'x1': 3.704224, 'x2': -8.728853}] as trial 18.
# [INFO 11-04 13:18:52] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:52] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:52] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:18:52] ax.service.ax_client: Completed trial 18 with data: {'t1': (470.654508, None)}.
# [INFO 11-04 13:18:52] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:18:52] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:52] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:18:52] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [ 3.70422448 -8.72885306]
#     trial_index arm_name trial_status generation_method           t1  \
# 0             0      0_0    COMPLETED            Manual  2594.000000
# 1             1      1_0    COMPLETED            Manual   954.000000
# 2             2      2_0    COMPLETED            Manual   314.000000
# 3             3      3_0    COMPLETED            Manual   914.000000
# 4             4      4_0    COMPLETED            Manual    74.000000
# 5             5      5_0    COMPLETED            Manual   234.000000
# 6             6      6_0    COMPLETED            Manual   234.000000
# 7             7      7_0    COMPLETED            Manual   194.000000
# 8             8      8_0    COMPLETED            Manual  1154.000000
# 9             9      9_0    COMPLETED            Manual   144.283766
# 10           10     10_0    COMPLETED            Manual   106.664881
# 11           11     11_0    COMPLETED            Manual    77.903815
# 12           12     12_0    COMPLETED            Manual    96.799838
# 13           13     13_0    COMPLETED            Manual   156.394816
# 14           14     14_0    COMPLETED            Manual   212.235726
# 15           15     15_0    COMPLETED            Manual   178.692409
# 16           16     16_0    COMPLETED            Manual   614.771521
# 17           17     17_0    COMPLETED            Manual    21.886454
# 18           18     18_0    COMPLETED            Manual   470.654508
#
#            x1         x2
# 0  -10.000000 -10.000000
# 1    0.000000 -10.000000
# 2   10.000000 -10.000000
# 3  -10.000000   0.000000
# 4    0.000000   0.000000
# 5   10.000000   0.000000
# 6  -10.000000  10.000000
# 7    0.000000  10.000000
# 8   10.000000  10.000000
# 9    5.008388  -5.010102
# 10  -5.139785   5.125778
# 11  -2.569313   2.539676
# 12   2.434446  -2.462556
# 13  -7.549616   7.611593
# 14   7.477880  -7.411117
# 15   6.229546   3.904894
# 16  -3.892278  -3.779069
# 17  -1.234204   6.393691
# 18   3.704224  -8.728853
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:18:55] ax.core.experiment: Attached custom parameterizations [{'x1': -6.366733, 'x2': 1.207574}] as trial 19.
# [INFO 11-04 13:18:55] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:55] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:18:55] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:18:55] ax.service.ax_client: Completed trial 19 with data: {'t1': (393.042314, None)}.
# [INFO 11-04 13:18:55] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# ...
# 1             1      1_0    COMPLETED            Manual   954.000000
# 2             2      2_0    COMPLETED            Manual   314.000000
# 3             3      3_0    COMPLETED            Manual   914.000000
# 4             4      4_0    COMPLETED            Manual    74.000000
# 5             5      5_0    COMPLETED            Manual   234.000000
# 6             6      6_0    COMPLETED            Manual   234.000000
# 7             7      7_0    COMPLETED            Manual   194.000000
# 8             8      8_0    COMPLETED            Manual  1154.000000
# 9             9      9_0    COMPLETED            Manual   166.704527
# 10           10     10_0    COMPLETED            Manual   888.805681
# 11           11     11_0    COMPLETED            Manual    76.856993
# 12           12     12_0    COMPLETED            Manual   157.162010
# 13           13     13_0    COMPLETED            Manual    77.263407
# 14           14     14_0    COMPLETED            Manual   443.573813
# 15           15     15_0    COMPLETED            Manual   632.812264
# 16           16     16_0    COMPLETED            Manual   331.370422
# 17           17     17_0    COMPLETED            Manual    80.596932
# 18           18     18_0    COMPLETED            Manual   369.269948
# 19           19     19_0    COMPLETED            Manual   561.273477
# 20           20     20_0    COMPLETED            Manual   222.547132
#
#            x1         x2
# 0  -10.000000 -10.000000
# 1    0.000000 -10.000000
# 2   10.000000 -10.000000
# 3  -10.000000   0.000000
# 4    0.000000   0.000000
# 5   10.000000   0.000000
# 6  -10.000000  10.000000
# 7    0.000000  10.000000
# 8   10.000000  10.000000
# 9    5.022176   5.027911
# 10  -5.022223  -5.015964
# 11  -2.543984   2.541274
# 12  -7.509469   7.491453
# 13   7.534614  -2.510987
# 14   2.503476  -7.578335
# 15  -1.315421  -6.311553
# 16   3.795748   8.729596
# 17   6.224004   1.329763
# 18  -3.806269  -1.250534
# 19   8.786997   6.279622
# 20  -6.284359   3.786937
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:24:46] ax.core.experiment: Attached custom parameterizations [{'x1': 1.275915, 'x2': -3.763813}] as trial 21.
# [INFO 11-04 13:24:46] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:24:46] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:24:46] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:24:46] ax.service.ax_client: Completed trial 21 with data: {'t1': (214.196562, None)}.
# [INFO 11-04 13:24:46] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:24:46] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:24:46] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:24:46] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [ 1.2759154  -3.76381308]
#     trial_index arm_name trial_status generation_method           t1  \
# 0             0      0_0    COMPLETED            Manual  2594.000000
# 1             1      1_0    COMPLETED            Manual   954.000000
# 2             2      2_0    COMPLETED            Manual   314.000000
# 3             3      3_0    COMPLETED            Manual   914.000000
# 4             4      4_0    COMPLETED            Manual    74.000000
# 5             5      5_0    COMPLETED            Manual   234.000000
# 6             6      6_0    COMPLETED            Manual   234.000000
# 7             7      7_0    COMPLETED            Manual   194.000000
# 8             8      8_0    COMPLETED            Manual  1154.000000
# 9             9      9_0    COMPLETED            Manual   166.704527
# 10           10     10_0    COMPLETED            Manual   888.805681
# 11           11     11_0    COMPLETED            Manual    76.856993
# 12           12     12_0    COMPLETED            Manual   157.162010
# 13           13     13_0    COMPLETED            Manual    77.263407
# 14           14     14_0    COMPLETED            Manual   443.573813
# 15           15     15_0    COMPLETED            Manual   632.812264
# 16           16     16_0    COMPLETED            Manual   331.370422
# 17           17     17_0    COMPLETED            Manual    80.596932
# 18           18     18_0    COMPLETED            Manual   369.269948
# 19           19     19_0    COMPLETED            Manual   561.273477
# 20           20     20_0    COMPLETED            Manual   222.547132
# 21           21     21_0    COMPLETED            Manual   214.196562
#
#            x1         x2
# 0  -10.000000 -10.000000
# 1    0.000000 -10.000000
# 2   10.000000 -10.000000
# 3  -10.000000   0.000000
# 4    0.000000   0.000000
# 5   10.000000   0.000000
# 6  -10.000000  10.000000
# 7    0.000000  10.000000
# 8   10.000000  10.000000
# 9    5.022176   5.027911
# 10  -5.022223  -5.015964
# 11  -2.543984   2.541274
# 12  -7.509469   7.491453
# 13   7.534614  -2.510987
# 14   2.503476  -7.578335
# 15  -1.315421  -6.311553
# 16   3.795748   8.729596
# 17   6.224004   1.329763
# 18  -3.806269  -1.250534
# 19   8.786997   6.279622
# 20  -6.284359   3.786937
# 21   1.275915  -3.763813
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:24:49] ax.core.experiment: Attached custom parameterizations [{'x1': -8.718308, 'x2': -8.672084}] as trial 22.
# [INFO 11-04 13:24:49] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:24:50] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:24:50] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:24:50] ax.service.ax_client: Completed trial 22 with data: {'t1': (2060.878654, None)}.
# [INFO 11-04 13:24:50] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:24:50] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:24:50] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [WARNING 11-04 13:24:50] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [-8.71830836 -8.67208426]
#     trial_index arm_name trial_status generation_method           t1  \
# 0             0      0_0    COMPLETED            Manual  2594.000000
# 1             1      1_0    COMPLETED            Manual   954.000000
# 2             2      2_0    COMPLETED            Manual   314.000000
# 3             3      3_0    COMPLETED            Manual   914.000000
# 4             4      4_0    COMPLETED            Manual    74.000000
# 5             5      5_0    COMPLETED            Manual   234.000000
# 6             6      6_0    COMPLETED            Manual   234.000000
# 7             7      7_0    COMPLETED            Manual   194.000000
# 8             8      8_0    COMPLETED            Manual  1154.000000
# 9             9      9_0    COMPLETED            Manual   166.704527
# 10           10     10_0    COMPLETED            Manual   888.805681
# 11           11     11_0    COMPLETED            Manual    76.856993
# 12           12     12_0    COMPLETED            Manual   157.162010
# 13           13     13_0    COMPLETED            Manual    77.263407
# 14           14     14_0    COMPLETED            Manual   443.573813
# 15           15     15_0    COMPLETED            Manual   632.812264
# 16           16     16_0    COMPLETED            Manual   331.370422
# 17           17     17_0    COMPLETED            Manual    80.596932
# 18           18     18_0    COMPLETED            Manual   369.269948
# 19           19     19_0    COMPLETED            Manual   561.273477
# 20           20     20_0    COMPLETED            Manual   222.547132
# 21           21     21_0    COMPLETED            Manual   214.196562
# 22           22     22_0    COMPLETED            Manual  2060.878654
#
#            x1         x2
# 0  -10.000000 -10.000000
# 1    0.000000 -10.000000
# 2   10.000000 -10.000000
# 3  -10.000000   0.000000
# 4    0.000000   0.000000
# 5   10.000000   0.000000
# 6  -10.000000  10.000000
# 7    0.000000  10.000000
# 8   10.000000  10.000000
# 9    5.022176   5.027911
# 10  -5.022223  -5.015964
# 11  -2.543984   2.541274
# 12  -7.509469   7.491453
# 13   7.534614  -2.510987
# 14   2.503476  -7.578335
# 15  -1.315421  -6.311553
# 16   3.795748   8.729596
# 17   6.224004   1.329763
# 18  -3.806269  -1.250534
# 19   8.786997   6.279622
# 20  -6.284359   3.786937
# 21   1.275915  -3.763813
# 22  -8.718308  -8.672084
# There are no trials currently running - initialising Bayesian iteration trials.
# [INFO 11-04 13:24:53] ax.core.experiment: Attached custom parameterizations [{'x1': -9.377419, 'x2': -4.3652}] as trial 23.
# [INFO 11-04 13:24:53] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:24:53] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /Users/thomasdodd/miniconda3/envs/BO4ACST_env/lib/python3.11/site-packages/ax/core/data.py:288: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 11-04 13:24:53] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [INFO 11-04 13:24:53] ax.service.ax_client: Completed trial 23 with data: {'t1': (1421.139016, None)}.
# [INFO 11-04 13:24:53] ax.service.ax_client: Saved JSON-serialized state of optimization to `/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/GitHub/BO4ACST/Notebooks/Optimisation/Method20241028Dim2_McIntersiteProj/AxExperiment.json`.
# [WARNING 11-04 13:24:53] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# [-9.37741876 -4.36519964]
#     trial_index arm_name trial_status generation_method           t1  \
# 0             0      0_0    COMPLETED            Manual  2594.000000
# 1             1      1_0    COMPLETED            Manual   954.000000
# 2             2      2_0    COMPLETED            Manual   314.000000
# 3             3      3_0    COMPLETED            Manual   914.000000
# 4             4      4_0    COMPLETED            Manual    74.000000
# 5             5      5_0    COMPLETED            Manual   234.000000
# 6             6      6_0    COMPLETED            Manual   234.000000
# 7             7      7_0    COMPLETED            Manual   194.000000
# 8             8      8_0    COMPLETED            Manual  1154.000000
# 9             9      9_0    COMPLETED            Manual   166.704527
# 10           10     10_0    COMPLETED            Manual   888.805681
# 11           11     11_0    COMPLETED            Manual    76.856993
# 12           12     12_0    COMPLETED            Manual   157.162010
# 13           13     13_0    COMPLETED            Manual    77.263407
# 14           14     14_0    COMPLETED            Manual   443.573813
# 15           15     15_0    COMPLETED            Manual   632.812264
# 16           16     16_0    COMPLETED            Manual   331.370422
# 17           17     17_0    COMPLETED            Manual    80.596932
# 18           18     18_0    COMPLETED            Manual   369.269948
# 19           19     19_0    COMPLETED            Manual   561.273477
# 20           20     20_0    COMPLETED            Manual   222.547132
# 21           21     21_0    COMPLETED            Manual   214.196562
# 22           22     22_0    COMPLETED            Manual  2060.878654
# 23           23     23_0    COMPLETED            Manual  1421.139016
#
#            x1         x2
# 0  -10.000000 -10.000000
# 1    0.000000 -10.000000
# 2   10.000000 -10.000000
# 3  -10.000000   0.000000
# 4    0.000000   0.000000
# 5   10.000000   0.000000
# 6  -10.000000  10.000000
# 7    0.000000  10.000000
# 8   10.000000  10.000000
# 9    5.022176   5.027911
# 10  -5.022223  -5.015964
# 11  -2.543984   2.541274
# 12  -7.509469   7.491453
# 13   7.534614  -2.510987
# 14   2.503476  -7.578335
# 15  -1.315421  -6.311553
# 16   3.795748   8.729596
# 17   6.224004   1.329763
# 18  -3.806269  -1.250534
# 19   8.786997   6.279622
# 20  -6.284359   3.786937
# 21   1.275915  -3.763813
# 22  -8.718308  -8.672084
# 23  -9.377419  -4.365200

# %%
t1Best_arr
# Out:
# array([21.88645414,  6.79882527, 14.40853939,  4.28939275, 13.02042787,
#         6.85385744, 22.31668936,  6.1035857 ,  9.23019391, 74.        ])

# %%
np.average(t1Best_arr)
# Out:
# 17.890796582533255

# %%
np.min(t1Best_arr)
# Out:
# 4.289392749138727
